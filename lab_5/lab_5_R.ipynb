# %%
install.packages("bnlearn")
install.packages("bnclassify")
q()
install.packages("e1071")
q()
install.packages("randomForest")
q()
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘assertthat’, ‘entropy’, ‘matrixStats’, ‘BH’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘proxy’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Load the bnlearn package
library(bnlearn)

# Read the data
data.grades<-read.table("2020_bn_nb_data.txt",head=TRUE)


head(data.grades)
# Out:
#   EC100 EC160 IT101 IT161 MA101 PH100 PH160 HS101 QP
# 1 BC    CC    BB    BC    CC    BC    AA    BB    y
# 2 CC    BC    BB    BB    CC    BC    AB    BB    y
# 3 AB    BB    AB    AB    BB    CC    BC    AB    y
# 4 BC    CC    BB    BB    BB    BB    BC    BB    y
# 5 BC    AB    CD    BC    BC    BC    BC    CD    y
# 6 DD    CC    DD    CD    CD    CC    BC    BC    n

# %%
# Assuming all these variables are problematic and need conversion
variables_to_convert <- c("EC100", "EC160", "IT101", "IT161", "MA101", "PH100", "PH160", "HS101", "QP")

data.grades[variables_to_convert] <- lapply(data.grades[variables_to_convert], as.factor)

data.grades.net<-hc(data.grades[,-9],score="k2")
plot(data.grades.net)
# Out:
# plot without title

# %%
# Learn the structure of the Bayesian network
network <- hc(data, score = "k2")

# %%
# Fit the network to the data to learn Conditional Probability Tables (CPTs)
network_fit <- bn.fit(network, data)

print(network_fit)
# Out:
#   Bayesian network parameters
#
#   Parameters of node EC100 (multinomial distribution)
#
# Conditional probability table:
#
#      MA101
# EC100         AA         AB         BB         BC         CC         CD
#    AA 0.75000000 0.07692308 0.03846154 0.01851852 0.00000000 0.00000000
#    AB 0.00000000 0.46153846 0.25000000 0.05555556 0.00000000 0.00000000
#    BB 0.25000000 0.23076923 0.32692308 0.22222222 0.04081633 0.00000000
#    BC 0.00000000 0.15384615 0.28846154 0.27777778 0.32653061 0.00000000
#    CC 0.00000000 0.07692308 0.09615385 0.24074074 0.32653061 0.04166667
#    CD 0.00000000 0.00000000 0.00000000 0.12962963 0.26530612 0.33333333
#    DD 0.00000000 0.00000000 0.00000000 0.03703704 0.04081633 0.50000000
#    F  0.00000000 0.00000000 0.00000000 0.01851852 0.00000000 0.12500000
#      MA101
# EC100         DD          F
#    AA 0.00000000 0.00000000
#    AB 0.00000000 0.00000000
#    BB 0.00000000 0.00000000
#    BC 0.00000000 0.00000000
#    CC 0.00000000 0.00000000
#    CD 0.04761905 0.00000000
#    DD 0.19047619 0.00000000
#    F  0.76190476 1.00000000
#
#   Parameters of node EC160 (multinomial distribution)
#
# Conditional probability table:
#
#      QP
# EC160          n          y
#    AA 0.00000000 0.07500000
#    AB 0.00000000 0.10000000
#    BB 0.01388889 0.18750000
#    BC 0.01388889 0.36250000
#    CC 0.15277778 0.22500000
#    CD 0.44444444 0.03125000
#    DD 0.26388889 0.01875000
#    F  0.11111111 0.00000000
#
#   Parameters of node IT101 (multinomial distribution)
#
# Conditional probability table:
#
#      QP
# IT101          n          y
#    AA 0.00000000 0.07500000
#    AB 0.00000000 0.15625000
#    BB 0.04166667 0.19375000
#    BC 0.02777778 0.29375000
#    CC 0.13888889 0.20000000
#    CD 0.30555556 0.08125000
#    DD 0.31944444 0.00000000
#    F  0.16666667 0.00000000
#
#   Parameters of node IT161 (multinomial distribution)
#
# Conditional probability table:
#
#      IT101
# IT161         AA         AB         BB         BC         CC         CD
#    AA 0.58333333 0.24000000 0.14705882 0.04081633 0.00000000 0.00000000
#    AB 0.16666667 0.40000000 0.29411765 0.02040816 0.04761905 0.00000000
#    BB 0.16666667 0.24000000 0.32352941 0.20408163 0.11904762 0.02857143
#    BC 0.08333333 0.04000000 0.20588235 0.36734694 0.38095238 0.17142857
#    CC 0.00000000 0.04000000 0.00000000 0.24489796 0.33333333 0.31428571
#    CD 0.00000000 0.04000000 0.02941176 0.10204082 0.09523810 0.31428571
#    DD 0.00000000 0.00000000 0.00000000 0.02040816 0.02380952 0.14285714
#    F  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.02857143
#      IT101
# IT161         DD          F
#    AA 0.00000000 0.00000000
#    AB 0.00000000 0.00000000
#    BB 0.00000000 0.00000000
#    BC 0.00000000 0.00000000
#    CC 0.08695652 0.16666667
#    CD 0.52173913 0.08333333
#    DD 0.39130435 0.58333333
#    F  0.00000000 0.16666667
#
#   Parameters of node MA101 (multinomial distribution)
#
# Conditional probability table:
#          AA         AB         BB         BC         CC         CD         DD
# 0.01724138 0.05603448 0.22413793 0.23275862 0.21120690 0.10344828 0.09051724
#          F
# 0.06465517
#
#   Parameters of node PH100 (multinomial distribution)
#
# Conditional probability table:
#
#      EC100
# PH100         AA         AB         BB         BC         CC         CD
#    AA 0.71428571 0.40909091 0.22857143 0.08333333 0.00000000 0.00000000
#    AB 0.14285714 0.31818182 0.20000000 0.18750000 0.05555556 0.00000000
#    BB 0.00000000 0.18181818 0.31428571 0.29166667 0.13888889 0.03448276
#    BC 0.14285714 0.04545455 0.14285714 0.22916667 0.33333333 0.13793103
#    CC 0.00000000 0.04545455 0.11428571 0.18750000 0.25000000 0.41379310
#    CD 0.00000000 0.00000000 0.00000000 0.02083333 0.19444444 0.31034483
#    DD 0.00000000 0.00000000 0.00000000 0.00000000 0.02777778 0.10344828
#    F  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#      EC100
# PH100         DD          F
#    AA 0.00000000 0.00000000
#    AB 0.00000000 0.00000000
#    BB 0.05000000 0.00000000
#    BC 0.00000000 0.00000000
#    CC 0.20000000 0.02857143
#    CD 0.45000000 0.11428571
#    DD 0.20000000 0.45714286
#    F  0.10000000 0.40000000
#
#   Parameters of node PH160 (multinomial distribution)
#
# Conditional probability table:
#
#      QP
# PH160          n          y
#    AA 0.05555556 0.14375000
#    AB 0.09722222 0.15625000
#    BB 0.02777778 0.17500000
#    BC 0.18055556 0.34375000
#    CC 0.29166667 0.13750000
#    CD 0.19444444 0.04375000
#    DD 0.12500000 0.00000000
#    F  0.02777778 0.00000000
#
#   Parameters of node HS101 (multinomial distribution)
#
# Conditional probability table:
#
#      QP
# HS101          n          y
#    AA 0.00000000 0.26250000
#    AB 0.00000000 0.21250000
#    BB 0.05555556 0.22500000
#    BC 0.12500000 0.16875000
#    CC 0.18055556 0.08125000
#    CD 0.19444444 0.03750000
#    DD 0.37500000 0.01250000
#    F  0.06944444 0.00000000
#
#   Parameters of node QP (multinomial distribution)
#
# Conditional probability table:
#
#    EC100
# QP         AA        AB        BB        BC        CC        CD        DD
#   n 0.0000000 0.0000000 0.0000000 0.0000000 0.1388889 0.4482759 0.9500000
#   y 1.0000000 1.0000000 1.0000000 1.0000000 0.8611111 0.5517241 0.0500000
#    EC100
# QP          F
#   n 1.0000000
#   y 0.0000000

# %%
# Define the grades for EC100, IT101, and MA101 for which we want to predict the grade in PH100
grades <- data.frame(EC100 = factor("DD", levels = levels(data$EC100)),
                     IT101 = factor("CC", levels = levels(data$IT101)),
                     MA101 = factor("CD", levels = levels(data$MA101)))

# Predict grade in PH100 given specific grades in other courses
predicted_grade_PH100 <- predict(network_fit, node = "PH100", method = "bayes-lw", data = grades)

# Print the predicted grade in PH100
print(predicted_grade_PH100)
# Out:
# [1] CD
# Levels: AA AB BB BC CC CD DD F

# %%
# Load the e1071 package
library(e1071)


course.grades <- read.table("2020_bn_nb_data.txt", header = TRUE)


course.grades <- data.frame(lapply(course.grades, as.factor))

# nuber of epochs
num_repetitions <- 20


accuracy_values <- numeric(num_repetitions)


for (i in 1:num_repetitions) {
  # Shuffle the data
  set.seed(i)
  course.grades <- course.grades[sample(nrow(course.grades)), ]

 # splitting data 70% training
  training_rows <- round(0.7 * nrow(course.grades))
  training_data <- course.grades[1:training_rows, ]
  testing_data <- course.grades[(training_rows + 1):nrow(course.grades), ]

  # Build Naive Bayes classifier
  model <- naiveBayes(QP ~ ., data = training_data)


  predictions <- predict(model, testing_data)

  # accuracy metrics takes parameters y_pred and y_true
  accuracy <- sum(predictions == testing_data$QP) / nrow(testing_data)


  accuracy_values[i] <- accuracy
  cat("Accuracy for repetition", i, ":", accuracy, "\n")

  # Confusion matrix metrics (y_pred,y_true)
  confusion_matrix <- table(Predicted = predictions, Actual = testing_data$QP)

  # Print confusion matrix (y_pred,y_true)
  cat("Confusion Matrix for repetition", i, ":\n")
  print(confusion_matrix)
  cat("\n")
}

# Calculate average accuracy
average_accuracy <- mean(accuracy_values)

# Print average accuracy
cat("Average Accuracy:", average_accuracy, "\n")
# Out:
# Accuracy for repetition 1 : 0.9714286
# Confusion Matrix for repetition 1 :
#          Actual
# Predicted  n  y
#         n 23  0
#         y  2 45
#
# Accuracy for repetition 2 : 0.9714286
# Confusion Matrix for repetition 2 :
#          Actual
# Predicted  n  y
#         n 17  0
#         y  2 51
#
# Accuracy for repetition 3 : 0.9714286
# Confusion Matrix for repetition 3 :
#          Actual
# Predicted  n  y
#         n 22  1
#         y  1 46
#
# Accuracy for repetition 4 : 0.9714286
# Confusion Matrix for repetition 4 :
#          Actual
# Predicted  n  y
#         n 19  1
#         y  1 49
#
# Accuracy for repetition 5 : 0.9857143
# Confusion Matrix for repetition 5 :
#          Actual
# Predicted  n  y
#         n 22  0
#         y  1 47
#
# Accuracy for repetition 6 : 0.9857143
# Confusion Matrix for repetition 6 :
#          Actual
# Predicted  n  y
#         n 22  0
#         y  1 47
#
# Accuracy for repetition 7 : 1
# Confusion Matrix for repetition 7 :
#          Actual
# Predicted  n  y
#         n 18  0
#         y  0 52
#
# Accuracy for repetition 8 : 1
# Confusion Matrix for repetition 8 :
#          Actual
# Predicted  n  y
#         n 16  0
#         y  0 54
#
# Accuracy for repetition 9 : 0.9714286
# Confusion Matrix for repetition 9 :
#          Actual
# Predicted  n  y
#         n 23  0
#         y  2 45
#
# Accuracy for repetition 10 : 0.9428571
# Confusion Matrix for repetition 10 :
#          Actual
# Predicted  n  y
#         n 22  1
#         y  3 44
#
# Accuracy for repetition 11 : 0.9571429
# Confusion Matrix for repetition 11 :
#          Actual
# Predicted  n  y
#         n 17  1
#         y  2 50
#
# Accuracy for repetition 12 : 1
# Confusion Matrix for repetition 12 :
#          Actual
# Predicted  n  y
#         n 16  0
#         y  0 54
#
# Accuracy for repetition 13 : 0.9857143
# Confusion Matrix for repetition 13 :
#          Actual
# Predicted  n  y
#         n 20  0
#         y  1 49
#
# Accuracy for repetition 14 : 0.9571429
# Confusion Matrix for repetition 14 :
#          Actual
# Predicted  n  y
#         n 21  2
#         y  1 46
#
# Accuracy for repetition 15 : 0.9714286
# Confusion Matrix for repetition 15 :
#          Actual
# Predicted  n  y
#         n 21  0
#         y  2 47
#
# Accuracy for repetition 16 : 0.9714286
# Confusion Matrix for repetition 16 :
#          Actual
# Predicted  n  y
#         n 22  1
#         y  1 46
#
# Accuracy for repetition 17 : 0.9571429
# Confusion Matrix for repetition 17 :
#          Actual
# Predicted  n  y
#         n 18  0
#         y  3 49
#
# Accuracy for repetition 18 : 0.9857143
# Confusion Matrix for repetition 18 :
#          Actual
# Predicted  n  y
#         n 18  0
#         y  1 51
#
# Accuracy for repetition 19 : 0.9857143
# Confusion Matrix for repetition 19 :
#          Actual
# Predicted  n  y
#         n 21  0
#         y  1 48
#
# Accuracy for repetition 20 : 0.9571429
# Confusion Matrix for repetition 20 :
#          Actual
# Predicted  n  y
#         n 19  0
#         y  3 48
#
# Average Accuracy: 0.975

# %%
library(randomForest)

course.grades <- read.table("2020_bn_nb_data.txt", header = TRUE)
course.grades <- data.frame(lapply(course.grades, as.factor))


num_repetitions <- 20
accuracy_values <- numeric(num_repetitions)

# number of trees in forest
num_trees <- 500

# training loop
for (i in 1:num_repetitions) {
  # Shuffle the data
  set.seed(i)
  course.grades <- course.grades[sample(nrow(course.grades)), ]


  training_rows <- round(0.7 * nrow(course.grades))
  training_data <- course.grades[1:training_rows, ]
  testing_data <- course.grades[(training_rows + 1):nrow(course.grades), ]

  # Build Random Forest classifier
  model <- randomForest(QP ~ ., data = training_data, ntree = num_trees)
  predictions <- predict(model, testing_data)

  accuracy <- sum(predictions == testing_data$QP) / nrow(testing_data)

  accuracy_values[i] <- accuracy
  cat("Accuracy for repetition", i, ":", accuracy, "\n")
  confusion_matrix <- table(Predicted = predictions, Actual = testing_data$QP)
  cat("Confusion Matrix for repetition", i, ":\n")
  print(confusion_matrix)
  cat("\n")
}


average_accuracy <- mean(accuracy_values)

# Printing average accuracy
cat("Average Accuracy:", average_accuracy, "\n")
# Out:
# Accuracy for repetition 1 : 0.9857143
# Confusion Matrix for repetition 1 :
#          Actual
# Predicted  n  y
#         n 25  1
#         y  0 44
#
# Accuracy for repetition 2 : 0.9857143
# Confusion Matrix for repetition 2 :
#          Actual
# Predicted  n  y
#         n 18  0
#         y  1 51
#
# Accuracy for repetition 3 : 0.9571429
# Confusion Matrix for repetition 3 :
#          Actual
# Predicted  n  y
#         n 22  2
#         y  1 45
#
# Accuracy for repetition 4 : 0.9428571
# Confusion Matrix for repetition 4 :
#          Actual
# Predicted  n  y
#         n 18  2
#         y  2 48
#
# Accuracy for repetition 5 : 0.9571429
# Confusion Matrix for repetition 5 :
#          Actual
# Predicted  n  y
#         n 21  1
#         y  2 46
#
# Accuracy for repetition 6 : 0.9428571
# Confusion Matrix for repetition 6 :
#          Actual
# Predicted  n  y
#         n 22  3
#         y  1 44
#
# Accuracy for repetition 7 : 0.9428571
# Confusion Matrix for repetition 7 :
#          Actual
# Predicted  n  y
#         n 18  4
#         y  0 48
#
# Accuracy for repetition 8 : 0.9857143
# Confusion Matrix for repetition 8 :
#          Actual
# Predicted  n  y
#         n 16  1
#         y  0 53
#
# Accuracy for repetition 9 : 0.9714286
# Confusion Matrix for repetition 9 :
#          Actual
# Predicted  n  y
#         n 24  1
#         y  1 44
#
# Accuracy for repetition 10 : 0.9428571
# Confusion Matrix for repetition 10 :
#          Actual
# Predicted  n  y
#         n 22  1
#         y  3 44
#
# Accuracy for repetition 11 : 0.9714286
# Confusion Matrix for repetition 11 :
#          Actual
# Predicted  n  y
#         n 18  1
#         y  1 50
#
# Accuracy for repetition 12 : 0.9428571
# Confusion Matrix for repetition 12 :
#          Actual
# Predicted  n  y
#         n 16  4
#         y  0 50
#
# Accuracy for repetition 13 : 0.9428571
# Confusion Matrix for repetition 13 :
#          Actual
# Predicted  n  y
#         n 21  4
#         y  0 45
#
# Accuracy for repetition 14 : 0.9714286
# Confusion Matrix for repetition 14 :
#          Actual
# Predicted  n  y
#         n 22  2
#         y  0 46
#
# Accuracy for repetition 15 : 0.9857143
# Confusion Matrix for repetition 15 :
#          Actual
# Predicted  n  y
#         n 22  0
#         y  1 47
#
# Accuracy for repetition 16 : 0.9428571
# Confusion Matrix for repetition 16 :
#          Actual
# Predicted  n  y
#         n 21  2
#         y  2 45
#
# Accuracy for repetition 17 : 0.9857143
# Confusion Matrix for repetition 17 :
#          Actual
# Predicted  n  y
#         n 21  1
#         y  0 48
#
# Accuracy for repetition 18 : 0.9571429
# Confusion Matrix for repetition 18 :
#          Actual
# Predicted  n  y
#         n 18  2
#         y  1 49
#
# Accuracy for repetition 19 : 0.9714286
# Confusion Matrix for repetition 19 :
#          Actual
# Predicted  n  y
#         n 21  1
#         y  1 47
#
# Accuracy for repetition 20 : 0.9714286
# Confusion Matrix for repetition 20 :
#          Actual
# Predicted  n  y
#         n 20  0
#         y  2 48
#
# Average Accuracy: 0.9628571
